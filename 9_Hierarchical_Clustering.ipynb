# %% [markdown]
# # HIERARCHICAL CLUSTERING

# %% [markdown]
# ### Import libraries

# %%
import warnings 
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ### Creating an artificial dataset

# %%
example_data = make_blobs(n_samples = 300, n_features = 2, centers = 3, cluster_std = 1.3)

print(example_data) # Check the dataset
# Out:
# (array([[ -1.2905831 ,  -9.06397519],
#        [ -1.46144902,  -7.69211797],
#        [ 10.36264331,   2.21464415],
#        [  8.42658941,   2.86198255],
#        [ -9.87407583,   3.84487927],
#        [  7.80047478,   3.19347424],
#        [ -8.35677942,   1.63410858],
#        [ -1.54445551,  -7.58058267],
#        [  8.91812495,   3.1280406 ],
#        [ -1.06554524,  -6.77637457],
#        [ -0.12496429,  -9.10450164],
#        [ 10.12983077,   4.44924068],
#        [ -9.2351851 ,   2.37299356],
#        [ -0.93907157,  -8.06735034],
#        [  8.13971647,   3.36596206],
#        [ -2.2026038 , -10.17724409],
#        [ -7.22161371,   3.51614599],
#        [ 10.06103973,   3.72820886],
#        [ -9.30270214,   2.24007903],
#        [  6.84266481,   6.14179227],
#        [  8.28276084,   2.2595493 ],
#        [ -8.83265637,   1.84304106],
#        [ -1.84361924, -11.96011765],
#        [  7.95741041,   2.00292967],
#        [ -8.60113892,   4.14411166],
# ...

# %% [markdown]
# ### Generating the dendogram

# %%
points = example_data[0]
dendogram = sch.dendrogram(sch.linkage(points, method = "ward"))

plt.figure(figsize=(4, 3))
plt.scatter(points[:,0], points[:,1])
plt.show()

# %% [markdown]
# ### Generating the hierarchical clustering

# %%
hierarchical_clustering = AgglomerativeClustering(n_clusters = 5, metric='euclidean', linkage='ward')

y_hierarch_clust = hierarchical_clustering.fit_predict(points)

plt.figure(figsize=(4, 3))
plt.scatter(points[y_hierarch_clust == 0,0], points[y_hierarch_clust == 0,1])
plt.scatter(points[y_hierarch_clust == 1,0], points[y_hierarch_clust == 1,1])
plt.scatter(points[y_hierarch_clust == 2,0], points[y_hierarch_clust == 2,1])
plt.scatter(points[y_hierarch_clust == 3,0], points[y_hierarch_clust == 3,1])
plt.scatter(points[y_hierarch_clust == 4,0], points[y_hierarch_clust == 4,1])
plt.show()
